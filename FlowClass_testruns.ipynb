# %%
using Pkg
Pkg.activate(".")
Pkg.instantiate()
# Out:
#   Activating project at `~/Library/CloudStorage/Dropbox/Landscape/CellMaths/Software/FlowClassv01.jl`
# Precompiling packages...
#    1148.4 ms  ? LinearSolve → LinearSolveSparseArraysExt
#    2001.1 ms  ? NonlinearSolveQuasiNewton
#    3170.8 ms  ? OrdinaryDiffEqDifferentiation
#    2551.8 ms  ? NonlinearSolveQuasiNewton → NonlinearSolveQuasiNewtonForwardDiffExt
#    2539.3 ms  ? OrdinaryDiffEqDifferentiation → OrdinaryDiffEqDifferentiationSparseArraysExt
#    2151.4 ms  ? OrdinaryDiffEqExtrapolation
#    3370.1 ms  ? OrdinaryDiffEqExponentialRK
#    4438.9 ms  ? OrdinaryDiffEqRosenbrock
#   13192.4 ms  ? NonlinearSolveFirstOrder
#    2296.4 ms  ? NonlinearSolve
#    2973.5 ms  ? NonlinearSolve → NonlinearSolveNLsolveExt
#    5379.4 ms  ? OrdinaryDiffEqNonlinearSolve
#    2167.2 ms  ? OrdinaryDiffEqFIRK
#    3349.1 ms  ? OrdinaryDiffEqStabilizedIRK
#    5596.6 ms  ? OrdinaryDiffEqIMEXMultistep
#   15627.6 ms  ? OrdinaryDiffEqPDIRK
#   17872.9 ms  ? OrdinaryDiffEqSDIRK
# ...

# %%
Pkg.test()
# Out:
#      Testing FlowClass
#       Status `/private/var/folders/g2/n20j20fx5yv_r5007tyqckd00000gn/T/jl_9OAHMh/Project.toml`
#   [85e7b882] FlowClass v0.1.0 `~/Library/CloudStorage/Dropbox/Landscape/CellMaths/Software/FlowClassv01.jl`
#   [37e2e46d] LinearAlgebra v1.12.0
#   [8dfed614] Test v1.11.0
#       Status `/private/var/folders/g2/n20j20fx5yv_r5007tyqckd00000gn/T/jl_9OAHMh/Manifest.toml`
#   [47edcb42] ADTypes v1.20.0
#   [7d9f7c33] Accessors v0.1.43
#   [79e6a3ab] Adapt v4.4.0
#   [4fba245c] ArrayInterface v7.22.0
#   [4c555306] ArrayLayouts v1.12.2
#   [62783981] BitTwiddlingConvenienceFunctions v0.1.6
#   [70df07ce] BracketingNonlinearSolve v1.6.0
#   [2a0fbf3d] CPUSummary v0.2.7
#   [d360d2e6] ChainRulesCore v1.26.0
#   [fb6a15b2] CloseOpenIntervals v0.1.13
#   [38540f10] CommonSolve v0.2.4
#   [bbf7d656] CommonSubexpressions v0.3.1
#   [f70d9fcc] CommonWorldInvalidations v1.0.0
#   [34da2185] Compat v4.18.1
#   [a33af91c] CompositionsBase v0.1.2
# ...
